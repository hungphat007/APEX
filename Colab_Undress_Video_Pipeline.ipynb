# %% [markdown]
# # Undress Video Pipeline — Google Colab T4 Runner
# Dedicated undress video processing engine using Wan 2.1-VACE-1.3B, SCHP ATR-18, SAM2, BiRefNet, InsightFace ArcFace, and RIFE optical flow temporal propagation.

# %% [markdown]
# ### Step 1: Check GPU Runtime
# Ensure runtime environment is set to T4 GPU (or RTX 3050 equivalent).

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 3: Run Video Reconstruction Pipeline
# Auto-downloads all required model weights automatically on Google Colab.

# %%
# Replace input.mp4 with your input video file path
# !python run.py --input input.mp4 --output result.mp4 --keyframe-interval 5 --candidates 2 --debug-masks

# %% [markdown]
# ### Step 4: Preview Output Video & Debug Visualization Mask

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open('result.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""<video width=600 controls><source src="{data_url}" type="video/mp4"></video>""")
